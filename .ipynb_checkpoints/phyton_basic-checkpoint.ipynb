# %%
print("Hello AI Architect Dereje!")
# Out:
# Hello AI Architect Dereje!

# %%
print("የመጀመሪያውን የ Python ትምህርት ጨርሻለሁ!")
# Out:
# የመጀመሪያውን የ Python ትምህርት ጨርሻለሁ!

# %%
#for loop


for number in range(4):
    print(number)
# Out:
# 0
# 1
# 2
# 3

# %%
for number in range(1,5):
   print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
for number in range(1,5):
    print(number , end= '')
# Out:
# 1234

# %%
number = 0
for number in range(10):
    if number == 5:
        break
    print('number is ' + str(number))
print('out of loop')
# Out:
# number is 0
# number is 1
# number is 2
# number is 3
# number is 4
# out of loop

# %%
for character in "information technology":
    print(character,end= '')
# Out:
# information technology

# %%
for outer_loop_number in range(1,3):

   for inner_loop_character in "ABC":
      print(outer_loop_number,inner_loop_character)
# Out:
# 1 A
# 1 B
# 1 C
# 2 A
# 2 B
# 2 C

# %%
#while loop

number = 0
while(number<7):
    print(number)
    number = number+2
# Out:
# 0
# 2
# 4
# 6

# %%
password = "data" 

for trial in range(1, 5):
    if trial == 4:
        print('one trial left')
        
    enter_password = input("Enter password :")
    
    if enter_password == password:
        print("Welcome to python ocurs!!")
        break
    else:
        print("wrong password!! ")
# Out:
# Enter password : rada
# wrong password!!
# Enter password : data
# Welcome to python ocurs!!

# %%
OTP = "1232"
is_verified = False
for trial in range(1,5):
    if trial == 4:
        print('one trial left!!!')
    enter_otp = input("Enter OTP:")
    if enter_otp!=OTP:
        print("Try again!!")
        continue
    else:
        name = input("Enter your name:")
        city_name = input("Enter your city:")
        break
if not is_verified:
    print("🔒 Account Locked! You have exceeded the maximum number of trials.")
# Out:
# Enter OTP: 75846
# Try again!!
# Enter OTP: 4464y
# Try again!!
# Enter OTP: 45646
# Try again!!
# one trial left!!!
# Enter OTP: 3556
# Try again!!
# 🔒 Account Locked! You have exceeded the maximum number of trials.
