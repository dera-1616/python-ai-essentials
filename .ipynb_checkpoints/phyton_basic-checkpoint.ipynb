# %%
print("Hello AI Architect Dereje!")
# Out:
# Hello AI Architect Dereje!

# %%
print("የመጀመሪያውን የ Python ትምህርት ጨርሻለሁ!")
# Out:
# የመጀመሪያውን የ Python ትምህርት ጨርሻለሁ!

# %%
for number in range(4):
    print(number)
# Out:
# 0
# 1
# 2
# 3

# %%
for number in range(1,5):
   print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
for number in range(1,5):
    print(number , end= '')
# Out:
# 1234

# %%
for character in "information technology":
    print(character,end= '')
# Out:
# information technology

# %%
for outer_loop_number in range(1,3):

   for inner_loop_character in "ABC":
      print(outer_loop_number,inner_loop_character)
# Out:
# 1 A
# 1 B
# 1 C
# 2 A
# 2 B
# 2 C

# %%
number = 0
while(number<7):
    print(number)
    number = number+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
